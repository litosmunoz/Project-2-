# %%
import pandas as pd
from pandas import json_normalize
import requests
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import  warnings
warnings.simplefilter("ignore")
import os
import json
from dotenv import load_dotenv

# %% [markdown]
# # Cleaning

# %%
# Read and see the dataset 
df = pd.read_csv ('../dataset/nft_sales.csv', encoding='unicode_escape')
df
# Out:
#      Rank           Collections           Sales     Buyers        Txns  \
# 0       1         Axie Infinity  $3,328,148,500  1,079,811   9,755,511
# 1       2           CryptoPunks  $1,664,246,968      4,723      18,961
# 2       3            Art Blocks  $1,075,223,906     20,934     117,602
# 3       4  Bored Ape Yacht Club    $783,882,186      8,284      22,584
# 4       5          NBA Top Shot    $781,965,423    374,818  11,790,699
# ..    ...                   ...             ...        ...         ...
# 245   246             Evolution      $2,536,468        746       4,961
# 246   247           LegionPunks      $2,535,490      1,702       3,794
# 247   248              BabyApes      $2,521,714      1,671       3,405
# 248   249  Train of the Century      $2,504,080      3,139      39,460
# 249   250      Cyber Pharmacist      $2,498,805      3,206       8,452
#
#         Owners
# 0    2,656,431
# 1        3,289
# 2       25,094
# 3        5,862
# 4      603,928
# ..         ...
# 245      2,061
# 246      2,410
# 247      2,785
# 248      3,160
# 249      3,689
#
# [250 rows x 6 columns]

# %%
# This dataset is from the 25th Nov 2021, we are going to clean, rename, drop and stay with the top 100 sorted by sales.
df['Buyers'] = df['Buyers'].str.replace(',', '')
df['Sales'] = df['Sales'].str.replace(',', '')
df['Sales'] = df['Sales'].str.replace('$', '')
df['Txns'] = df['Txns'].str.replace(',', '')
df = df.rename(columns = {'Sales': 'USD_Sales_not_updated', 'Buyers' : 'Buyers_not_updated', 'Txns' : 'Txns_not_updated'})
df['Collections'] = df['Collections'].astype('string')
df['USD_Sales_not_updated'] = pd.to_numeric(df['USD_Sales_not_updated'])
df['Buyers_not_updated'] = pd.to_numeric(df['Buyers_not_updated'])
df['Txns_not_updated'] = pd.to_numeric(df['Txns_not_updated'])
df = df.drop(columns=['Owners'])
df = df[:100]
df.head()
# Out:
#    Rank           Collections  USD_Sales_not_updated  Buyers_not_updated  \
# 0     1         Axie Infinity             3328148500             1079811
# 1     2           CryptoPunks             1664246968                4723
# 2     3            Art Blocks             1075223906               20934
# 3     4  Bored Ape Yacht Club              783882186                8284
# 4     5          NBA Top Shot              781965423              374818
#
#    Txns_not_updated
# 0           9755511
# 1             18961
# 2            117602
# 3             22584
# 4          11790699

# %%
# Add a usd per transaction column, add a usd per buyer, add transaction per buyers and convert sales to usd million.
df['$/Txn_not_updated'] = df['USD_Sales_not_updated'] // df['Txns_not_updated']
df['$/Buyer_not_updated'] = df['USD_Sales_not_updated'] // df['Buyers_not_updated']
df['Txn/Buyer_not_updated'] = df['Txns_not_updated'] / df['Buyers_not_updated']
df['USD_Sales_not_updated'] = df['USD_Sales_not_updated'] / 1e6
df = df.rename(columns = {'USD_Sales_not_updated': 'USD_Sales_in_millions_not_updated'})
df
# Out:
#     Rank           Collections  USD_Sales_in_millions_not_updated  \
# 0      1         Axie Infinity                        3328.148500
# 1      2           CryptoPunks                        1664.246968
# 2      3            Art Blocks                        1075.223906
# 3      4  Bored Ape Yacht Club                         783.882186
# 4      5          NBA Top Shot                         781.965423
# ..   ...                   ...                                ...
# 95    96             Solsteads                          17.915196
# 96    97     Galaxy Fight Club                          17.903757
# 97    98            CryptoArte                          17.817569
# 98    99       Forgotten Runes                          17.729910
# 99   100        Mike Tyson NFT                          17.537597
#
#     Buyers_not_updated  Txns_not_updated  $/Txn_not_updated  \
# 0              1079811           9755511                341
# 1                 4723             18961              87772
# 2                20934            117602               9142
# 3                 8284             22584              34709
# 4               374818          11790699                 66
# ..                 ...               ...                ...
# 95                1621              3120               5742
# 96                4232             13866               1291
# 97                4121              9709               1835
# 98                3620             11562               1533
# 99                 756              1413              12411
#
#     $/Buyer_not_updated  Txn/Buyer_not_updated
# 0                  3082               9.034462
# 1                352370               4.014609
# 2                 51362               5.617751
# 3                 94626               2.726219
# 4                  2086              31.457131
# ..                  ...                    ...
# 95                11051               1.924738
# 96                 4230               3.276465
# 97                 4323               2.355982
# 98                 4897               3.193923
# 99                23197               1.869048
#
# [100 rows x 8 columns]

# %%
# Load token to access API
load_dotenv()
token = os.getenv('token')

# %%
import requests

url = "https://api.cryptoslam.io/im6pi8nxcs120nhb/v1/collections/top-100?timeRange=all"
headers = {
  "X-BLOBR-KEY": token
}
response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"data":[{"rank":1,"collectionImageURL":"https://d1nht67oz99wd1.cloudfront.net/resized/axie-infinity-logo_resized.png","collectionName":"Axie Infinity","collectionId":"axie-infinity","paymentToken":"ETH","buyerCount":1791631,"sellerCount":1337430,"transactionCount":17718939,"salesVolumeChangePercentage":0,"blockchainId":"ronin","quote":{"USD":{"salesVolume":4090984208.7145714389549359162,"previousSalesVolume":0.0},"ETH":{"salesVolume":1328209.4404534904931958260020,"previousSalesVolume":0.0}}},{"rank":2,"collectionImageURL":"https://cryptoslam-token-images.s3.amazonaws.com/icons/bored ape yatch club.png","collectionName":"Bored Ape Yacht Club","collectionId":"bored-ape-yacht-club","paymentToken":"ETH","buyerCount":12071,"sellerCount":9521,"transactionCount":32743,"salesVolumeChangePercentage":0.0,"blockchainId":"ethereum","quote":{"USD":{"salesVolume":2446885967.71,"previousSalesVolume":2446885967.71},"ETH":{"salesVolume":18665748.1030449,"previousSalesVolume":18665748.1030449}}},{"rank":3,"collectionImageURL":"https://d1nht67oz99wd1.cloudfront.net/resized/cryptopunks-logo_resized.png","collectionName":"CryptoPunks","collectionId":"cryptopunks","paymentToken":"ETH","buyerCount":6088,"sellerCount":4083,"transactionCount":22292,"salesVolumeChangePercentage":0,"blockchainId":"ethereum","quote":{"USD":{"salesVolume":2392128016.9632950262655803071,"previousSalesVolume":0.0},"ETH":{"salesVolume":895410.8223494985087385115078,"previousSalesVolume":0.0}}},{"rank":4,"collectionImageURL":"https://d1nht67oz99wd1.cloudfront.net/resized/mutant-ape-yacht-club_resized.png","collectionName":"Mutant Ape Yacht Club","collectionId":"mutant-ape-yacht-club","paymentToken":"ETH","buyerCount":23847,"sellerCount":18747,"transactionCount":51995,"salesVolumeChangePercentage":0.0,"blockchainId":"ethereum","quote":{"USD":{"salesVolume":1749301673.63,"previousSalesVolume":1749301673.63},"ETH":{"salesVolume":102520512.485297,"previousSalesVolume":102520512.485298}}},{"rank":5,"collectionImageURL":"https://d1nht67oz99wd1.cloudfront.net/resized/art-blocks-logo2_resized.png","collectionName":"Art Blocks","collectionId":"art-blocks","paymentToken":"ETH","buyerCount":33648,"sellerCount":33375,"transactionCount":185253,"salesVolumeChangePercentage":0,"blockchainId":"ethereum","quote":{"USD":{"salesVolume":1311728715.0636414009743931200,"previousSalesVolume":0.0},"ETH":{"salesVolume":436985.75483143182322728427556,"previousSalesVolume":0.0}}},{"rank":6,"collectionImageURL":"https://cryptoslam-token-images.s3.amazonaws.com/icons/otherdeed.png","collectionName":"Otherdeed","collectionId":"otherdeed","paymentToken":"ETH","buyerCount":26641,"sellerCount":23118,"transactionCount":59966,"salesVolumeChangePercentage":0.0,"blockchainId":"ethereum","quote":{"USD":{"salesVolume":1055428408.14,"previousSalesVolume":1055428408.14},"ETH":{"salesVolume":417909.293370506,"previousSalesVolume":417909.293370506}}},{"rank":7,"collectionImageURL":"https://d1nht67oz99wd1.cloudfront.net/nba-top-shot-v2-logo.png","collectionName":"NBA Top Shot","collectionId":"nba-top-shot","paymentToken":"Flow","buyerCount":446665,"sellerCount":436159,"transactionCount":21862169,"salesVolumeChangePercentage":0,"blockchainId":"flow","quote":{"USD":{"salesVolume":1033386630.38000000,"previousSalesVolume":0.0},"Flow":{"salesVolume":1033386630.38000000,"previousSalesVolume":0.0}}},{"rank":8,"collectionImageURL":"https://cryptoslam-token-images.s3.amazonaws.com/icons/azuki.png","collectionName":"Azuki","collectionId":"azuki","paymentToken":"ETH","buyerCount":14837,"sellerCount":13089,"transactionCount":33024,"salesVolumeChangePercentage":0.0,"blockchainId":"ethereum","quote":{"USD":{"salesVolume":803836783.18,"previousSalesVolume":803836783.18},"ETH":{"salesVolume":434547.04200082,"previousSalesVolume":434547.04200082}}},{"rank":9,"collectionImageURL":"https://d1nht67oz99wd1.cloudfront.net/clonex.jpeg","collectionName":"CloneX","collectionId":"clonex","paymentToken":"ETH","buyerCount":11602,"sellerCount": ...

# %%
# Normalize data from API
df_api = json_normalize(response.json()['data'])
df_api.head()
# Out:
#    rank                                 collectionImageURL  \
# 0     1  https://d1nht67oz99wd1.cloudfront.net/resized/...
# 1     2  https://cryptoslam-token-images.s3.amazonaws.c...
# 2     3  https://d1nht67oz99wd1.cloudfront.net/resized/...
# 3     4  https://d1nht67oz99wd1.cloudfront.net/resized/...
# 4     5  https://d1nht67oz99wd1.cloudfront.net/resized/...
#
#           collectionName           collectionId paymentToken  buyerCount  \
# 0          Axie Infinity          axie-infinity          ETH     1791631
# 1   Bored Ape Yacht Club   bored-ape-yacht-club          ETH       12071
# 2            CryptoPunks            cryptopunks          ETH        6088
# 3  Mutant Ape Yacht Club  mutant-ape-yacht-club          ETH       23847
# 4             Art Blocks             art-blocks          ETH       33648
#
#    sellerCount  transactionCount  salesVolumeChangePercentage blockchainId  \
# 0      1337430          17718939                          0.0        ronin
# 1         9521             32743                          0.0     ethereum
# 2         4083             22292                          0.0     ethereum
# 3        18747             51995                          0.0     ethereum
# 4        33375            185253                          0.0     ethereum
#
#    quote.USD.salesVolume  quote.USD.previousSalesVolume  \
# 0           4.090984e+09                   0.000000e+00
# 1           2.446886e+09                   2.446886e+09
# 2           2.392128e+09                   0.000000e+00
# 3           1.749302e+09                   1.749302e+09
# 4           1.311729e+09                   0.000000e+00
#
#    quote.ETH.salesVolume  quote.ETH.previousSalesVolume  \
# 0           1.328209e+06                   0.000000e+00
# 1           1.866575e+07                   1.866575e+07
# 2           8.954108e+05                   0.000000e+00
# 3           1.025205e+08                   1.025205e+08
# 4           4.369858e+05                   0.000000e+00
#
#    quote.Flow.salesVolume  quote.Flow.previousSalesVolume  \
# 0                     NaN                             NaN
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
#
#    quote.WAX.salesVolume  quote.WAX.previousSalesVolume  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN                            NaN
# 4                    NaN                            NaN
#
#    quote.SOL.salesVolume  quote.SOL.previousSalesVolume
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN                            NaN
# 4                    NaN                            NaN

# %%
#Clean API dataframe to get the data needed for investigation
df_api = df_api[['rank', 'blockchainId', 'collectionName','quote.USD.salesVolume', 'buyerCount', 'transactionCount']]
df_api = df_api.rename(columns = {'rank' : 'Rank_Updated', 'collectionName' : 'Collections', 'buyerCount' : 'Buyers_Updated', 'transactionCount' : 'Txns_Updated', 'quote.USD.salesVolume': 'USD_Sales_Updated'})
df_api['Collections'] = df_api['Collections'].astype('string')
df_api['blockchainId']= df_api['blockchainId'].astype('string')
df_api.head()
# Out:
#    Rank_Updated blockchainId            Collections  USD_Sales_Updated  \
# 0             1        ronin          Axie Infinity       4.090984e+09
# 1             2     ethereum   Bored Ape Yacht Club       2.446886e+09
# 2             3     ethereum            CryptoPunks       2.392128e+09
# 3             4     ethereum  Mutant Ape Yacht Club       1.749302e+09
# 4             5     ethereum             Art Blocks       1.311729e+09
#
#    Buyers_Updated  Txns_Updated
# 0         1791631      17718939
# 1           12071         32743
# 2            6088         22292
# 3           23847         51995
# 4           33648        185253

# %%
#Create new columns, showing the kpis to be able to compare.
df_api['$/Txn_Updated'] = df_api['USD_Sales_Updated'] // df_api['Txns_Updated']
df_api['$/Txn_Updated'] = df_api['$/Txn_Updated'].astype('int64')
df_api['$/Buyer_Updated'] = df_api['USD_Sales_Updated'] // df_api['Buyers_Updated']
df_api['$/Buyer_Updated'] = df_api['$/Buyer_Updated'].astype('int64')
df_api['Txn/Buyer_Updated'] = df_api['Txns_Updated'] / df_api['Buyers_Updated']
df_api['USD_Sales_Updated'] = df_api['USD_Sales_Updated'] / 1e6
df_api = df_api.rename(columns = {'USD_Sales_Updated': 'USD_Sales_in_millions_Updated'})
df_api.head()
# Out:
#    Rank_Updated blockchainId            Collections  \
# 0             1        ronin          Axie Infinity
# 1             2     ethereum   Bored Ape Yacht Club
# 2             3     ethereum            CryptoPunks
# 3             4     ethereum  Mutant Ape Yacht Club
# 4             5     ethereum             Art Blocks
#
#    USD_Sales_in_millions_Updated  Buyers_Updated  Txns_Updated  $/Txn_Updated  \
# 0                    4090.984209         1791631      17718939            230
# 1                    2446.885968           12071         32743          74730
# 2                    2392.128017            6088         22292         107308
# 3                    1749.301674           23847         51995          33643
# 4                    1311.728715           33648        185253           7080
#
#    $/Buyer_Updated  Txn/Buyer_Updated
# 0             2283           9.889837
# 1           202707           2.712534
# 2           392925           3.661629
# 3            73355           2.180358
# 4            38983           5.505617

# %%
# List collections to be able to compare changes
Collections_before = df['Collections'].tolist()
Collections_after = df_api['Collections'].tolist()

# %%
# We are going to create a list with the collections that were at the top 100 from the original dataset and see how many of them still are at the top 100. The collections that remain at the top 100 will have a @ before the name.
def Collections_sorted(collections_column):
    Comparing_Collections_before = []
    for i in range(len(Collections_before)):
        new_name = str(Collections_before[i])
        if new_name in Collections_after:
            Comparing_Collections_before.append('@' + new_name)  
        elif new_name not in Collections_after:
            Comparing_Collections_before.append(new_name) 
    return(Comparing_Collections_before)

# %%
df['Collections']= Collections_sorted(list(df['Collections']))
df.head()
# Out:
#    Rank            Collections  USD_Sales_in_millions_not_updated  \
# 0     1         @Axie Infinity                        3328.148500
# 1     2           @CryptoPunks                        1664.246968
# 2     3            @Art Blocks                        1075.223906
# 3     4  @Bored Ape Yacht Club                         783.882186
# 4     5          @NBA Top Shot                         781.965423
#
#    Buyers_not_updated  Txns_not_updated  $/Txn_not_updated  \
# 0             1079811           9755511                341
# 1                4723             18961              87772
# 2               20934            117602               9142
# 3                8284             22584              34709
# 4              374818          11790699                 66
#
#    $/Buyer_not_updated  Txn/Buyer_not_updated
# 0                 3082               9.034462
# 1               352370               4.014609
# 2                51362               5.617751
# 3                94626               2.726219
# 4                 2086              31.457131

# %%
# We do the same for the dataset extracted from the API.
def Collections_sorted_api(collections_column):
    Comparing_Collections_after = []
    for i in range(len(Collections_after)):
        new_name = str(Collections_after[i])
        if new_name in Collections_before: 
            Comparing_Collections_after.append('@' + new_name)  
        elif new_name not in Collections_before:
            Comparing_Collections_after.append(new_name)
    return(Comparing_Collections_after)

# %%
df_api['Collections']= Collections_sorted_api(list(df_api['Collections']))
df_api.head()
# Out:
#    Rank_Updated blockchainId             Collections  \
# 0             1        ronin          @Axie Infinity
# 1             2     ethereum   @Bored Ape Yacht Club
# 2             3     ethereum            @CryptoPunks
# 3             4     ethereum  @Mutant Ape Yacht Club
# 4             5     ethereum             @Art Blocks
#
#    USD_Sales_in_millions_Updated  Buyers_Updated  Txns_Updated  $/Txn_Updated  \
# 0                    4090.984209         1791631      17718939            230
# 1                    2446.885968           12071         32743          74730
# 2                    2392.128017            6088         22292         107308
# 3                    1749.301674           23847         51995          33643
# 4                    1311.728715           33648        185253           7080
#
#    $/Buyer_Updated  Txn/Buyer_Updated
# 0             2283           9.889837
# 1           202707           2.712534
# 2           392925           3.661629
# 3            73355           2.180358
# 4            38983           5.505617

# %%
# We will work only with the data from the collections that have remained in the top 100. 
NFT_collections_that_remain_in_top100 = df[df['Collections'].str.contains('@')==True]
NFT_collections_that_remain_in_top100.set_index('Collections', inplace=True)
NFT_collections_that_remain_in_top100.head()
# Out:
#                        Rank  USD_Sales_in_millions_not_updated  \
# Collections
# @Axie Infinity            1                        3328.148500
# @CryptoPunks              2                        1664.246968
# @Art Blocks               3                        1075.223906
# @Bored Ape Yacht Club     4                         783.882186
# @NBA Top Shot             5                         781.965423
#
#                        Buyers_not_updated  Txns_not_updated  \
# Collections
# @Axie Infinity                    1079811           9755511
# @CryptoPunks                         4723             18961
# @Art Blocks                         20934            117602
# @Bored Ape Yacht Club                8284             22584
# @NBA Top Shot                      374818          11790699
#
#                        $/Txn_not_updated  $/Buyer_not_updated  \
# Collections
# @Axie Infinity                       341                 3082
# @CryptoPunks                       87772               352370
# @Art Blocks                         9142                51362
# @Bored Ape Yacht Club              34709                94626
# @NBA Top Shot                         66                 2086
#
#                        Txn/Buyer_not_updated
# Collections
# @Axie Infinity                      9.034462
# @CryptoPunks                        4.014609
# @Art Blocks                         5.617751
# @Bored Ape Yacht Club               2.726219
# @NBA Top Shot                      31.457131

# %%
NFT_collections_that_remain_top100_Updated = df_api[df_api['Collections'].str.contains('@')==True]
NFT_collections_that_remain_top100_Updated.set_index('Collections', inplace=True)
NFT_collections_that_remain_top100_Updated.head()
# Out:
#                         Rank_Updated blockchainId  \
# Collections
# @Axie Infinity                     1        ronin
# @Bored Ape Yacht Club              2     ethereum
# @CryptoPunks                       3     ethereum
# @Mutant Ape Yacht Club             4     ethereum
# @Art Blocks                        5     ethereum
#
#                         USD_Sales_in_millions_Updated  Buyers_Updated  \
# Collections
# @Axie Infinity                            4090.984209         1791631
# @Bored Ape Yacht Club                     2446.885968           12071
# @CryptoPunks                              2392.128017            6088
# @Mutant Ape Yacht Club                    1749.301674           23847
# @Art Blocks                               1311.728715           33648
#
#                         Txns_Updated  $/Txn_Updated  $/Buyer_Updated  \
# Collections
# @Axie Infinity              17718939            230             2283
# @Bored Ape Yacht Club          32743          74730           202707
# @CryptoPunks                   22292         107308           392925
# @Mutant Ape Yacht Club         51995          33643            73355
# @Art Blocks                   185253           7080            38983
#
#                         Txn/Buyer_Updated
# Collections
# @Axie Infinity                   9.889837
# @Bored Ape Yacht Club            2.712534
# @CryptoPunks                     3.661629
# @Mutant Ape Yacht Club           2.180358
# @Art Blocks                      5.505617

# %%
# We concatenate dataframes, setting Collections as the common index.
NFT_collections_csv = pd.concat([NFT_collections_that_remain_in_top100, NFT_collections_that_remain_top100_Updated], axis=1)
NFT_collections_csv.head()
# Out:
#                        Rank  USD_Sales_in_millions_not_updated  \
# Collections
# @Axie Infinity            1                        3328.148500
# @CryptoPunks              2                        1664.246968
# @Art Blocks               3                        1075.223906
# @Bored Ape Yacht Club     4                         783.882186
# @NBA Top Shot             5                         781.965423
#
#                        Buyers_not_updated  Txns_not_updated  \
# Collections
# @Axie Infinity                    1079811           9755511
# @CryptoPunks                         4723             18961
# @Art Blocks                         20934            117602
# @Bored Ape Yacht Club                8284             22584
# @NBA Top Shot                      374818          11790699
#
#                        $/Txn_not_updated  $/Buyer_not_updated  \
# Collections
# @Axie Infinity                       341                 3082
# @CryptoPunks                       87772               352370
# @Art Blocks                         9142                51362
# @Bored Ape Yacht Club              34709                94626
# @NBA Top Shot                         66                 2086
#
#                        Txn/Buyer_not_updated  Rank_Updated blockchainId  \
# Collections
# @Axie Infinity                      9.034462             1        ronin
# @CryptoPunks                        4.014609             3     ethereum
# @Art Blocks                         5.617751             5     ethereum
# @Bored Ape Yacht Club               2.726219             2     ethereum
# @NBA Top Shot                      31.457131             7         flow
#
#                        USD_Sales_in_millions_Updated  Buyers_Updated  \
# Collections
# @Axie Infinity                           4090.984209         1791631
# @CryptoPunks                             2392.128017            6088
# @Art Blocks                              1311.728715           33648
# @Bored Ape Yacht Club                    2446.885968           12071
# @NBA Top Shot                            1033.386630          446665
#
#                        Txns_Updated  $/Txn_Updated  $/Buyer_Updated  \
# Collections
# @Axie Infinity             17718939            230             2283
# @CryptoPunks                  22292         107308           392925
# @Art Blocks                  185253           7080            38983
# @Bored Ape Yacht Club         32743          74730           202707
# @NBA Top Shot              21862169             47             2313
#
#                        Txn/Buyer_Updated
# Collections
# @Axie Infinity                  9.889837
# @CryptoPunks                    3.661629
# @Art Blocks                     5.505617
# @Bored Ape Yacht Club           2.712534
# @NBA Top Shot                  48.945337

# %%
# For convenience I decided to split the main dataframe, the first one containing the original data and the second one containing the main kpis.
# Save concatenated dataframes.
NFT_data = NFT_collections_csv[['Rank', 'Rank_Updated','blockchainId', 'USD_Sales_in_millions_not_updated', 'USD_Sales_in_millions_Updated', 'Buyers_not_updated', 'Buyers_Updated', 'Txns_not_updated', 'Txns_Updated']]
NFT_data.head()
NFT_data.to_csv('../dataset/NFT_data.csv')

# %%
NFT_kpis = NFT_collections_csv[['blockchainId', '$/Txn_not_updated', '$/Txn_Updated', '$/Buyer_not_updated', '$/Buyer_Updated', 'Txn/Buyer_not_updated','Txn/Buyer_Updated']]
NFT_kpis.head()
# Out:
#                       blockchainId  $/Txn_not_updated  $/Txn_Updated  \
# Collections
# @Axie Infinity               ronin                341            230
# @CryptoPunks              ethereum              87772         107308
# @Art Blocks               ethereum               9142           7080
# @Bored Ape Yacht Club     ethereum              34709          74730
# @NBA Top Shot                 flow                 66             47
#
#                        $/Buyer_not_updated  $/Buyer_Updated  \
# Collections
# @Axie Infinity                        3082             2283
# @CryptoPunks                        352370           392925
# @Art Blocks                          51362            38983
# @Bored Ape Yacht Club                94626           202707
# @NBA Top Shot                         2086             2313
#
#                        Txn/Buyer_not_updated  Txn/Buyer_Updated
# Collections
# @Axie Infinity                      9.034462           9.889837
# @CryptoPunks                        4.014609           3.661629
# @Art Blocks                         5.617751           5.505617
# @Bored Ape Yacht Club               2.726219           2.712534
# @NBA Top Shot                      31.457131          48.945337

# %%
# To further understand the kpis I decided to explore the variations from the original dataset until now. Created three more columns. 
# Example 1: A $/Txn variation greater than 1 means that more USD has been spent per transaction.
# Example 2: A $/Buyer variation greater than 1 means that more USD has been spent per buyer.
# Example 3: A Txn/Buyer variation greater than 1 means that each buyer has done more than one transaction.
NFT_kpis['$/Txn_variation'] = NFT_kpis['$/Txn_Updated'] / NFT_kpis['$/Txn_not_updated']
NFT_kpis['$/Buyer_variation'] = NFT_kpis['$/Buyer_Updated'] / NFT_kpis['$/Buyer_not_updated']
NFT_kpis['Txn/Buyer_variation'] = NFT_kpis['Txn/Buyer_Updated'] / NFT_kpis['Txn/Buyer_not_updated']
NFT_kpis.to_csv('../dataset/NFT_kpis.csv')
NFT_kpis.head()
# Out:
#                       blockchainId  $/Txn_not_updated  $/Txn_Updated  \
# Collections
# @Axie Infinity               ronin                341            230
# @CryptoPunks              ethereum              87772         107308
# @Art Blocks               ethereum               9142           7080
# @Bored Ape Yacht Club     ethereum              34709          74730
# @NBA Top Shot                 flow                 66             47
#
#                        $/Buyer_not_updated  $/Buyer_Updated  \
# Collections
# @Axie Infinity                        3082             2283
# @CryptoPunks                        352370           392925
# @Art Blocks                          51362            38983
# @Bored Ape Yacht Club                94626           202707
# @NBA Top Shot                         2086             2313
#
#                        Txn/Buyer_not_updated  Txn/Buyer_Updated  \
# Collections
# @Axie Infinity                      9.034462           9.889837
# @CryptoPunks                        4.014609           3.661629
# @Art Blocks                         5.617751           5.505617
# @Bored Ape Yacht Club               2.726219           2.712534
# @NBA Top Shot                      31.457131          48.945337
#
#                        $/Txn_variation  $/Buyer_variation  Txn/Buyer_variation
# Collections
# @Axie Infinity                0.674487           0.740753             1.094679
# @CryptoPunks                  1.222577           1.115092             0.912076
# @Art Blocks                   0.774448           0.758985             0.980039
# @Bored Ape Yacht Club         2.153044           2.142191             0.994980
# @NBA Top Shot                 0.712121           1.108821             1.555938

# %%
# Create a new dataframe with blockchain Id and variations for convenience.
NFT_kpis_variation = NFT_kpis[['blockchainId', '$/Txn_variation', '$/Buyer_variation', 'Txn/Buyer_variation']]
NFT_kpis_variation.head()
# Out:
#                       blockchainId  $/Txn_variation  $/Buyer_variation  \
# Collections
# @Axie Infinity               ronin         0.674487           0.740753
# @CryptoPunks              ethereum         1.222577           1.115092
# @Art Blocks               ethereum         0.774448           0.758985
# @Bored Ape Yacht Club     ethereum         2.153044           2.142191
# @NBA Top Shot                 flow         0.712121           1.108821
#
#                        Txn/Buyer_variation
# Collections
# @Axie Infinity                    1.094679
# @CryptoPunks                      0.912076
# @Art Blocks                       0.980039
# @Bored Ape Yacht Club             0.994980
# @NBA Top Shot                     1.555938

# %%
# We are going to do some calculations per variable, the results will then be added to the final dataframe that we will use to conclude.
a1 = NFT_kpis_variation['$/Txn_variation'].min()
print(a1)
a2 = NFT_kpis_variation['$/Txn_variation'].median()
print(a2)
a3 = NFT_kpis_variation['$/Txn_variation'].mean()
print(a3)
a4 = NFT_kpis_variation['$/Txn_variation'].max()
print(a4)
a5= NFT_kpis_variation['$/Txn_variation'].std()
print(a5)
# Out:
# 0.11538461538461539
# 0.938092166370297
# 1.1138836700544108
# 2.552621101526211
# 0.485025795673958

# %%
b1 = NFT_kpis_variation['$/Buyer_variation'].min()
print(b1)
b2 = NFT_kpis_variation['$/Buyer_variation'].median()
print(b2)
b3 = NFT_kpis_variation['$/Buyer_variation'].mean()
print(b3)
b4 = NFT_kpis_variation['$/Buyer_variation'].max()
print(b4)
b5 = NFT_kpis_variation['$/Buyer_variation'].std()
print(b5)
# Out:
# 0.3421699918010385
# 0.9915182868326075
# 1.1557626869657742
# 2.8152
# 0.4808588558087434

# %%
c1 = NFT_kpis_variation['Txn/Buyer_variation'].min()
print(c1)
c2 = NFT_kpis_variation['Txn/Buyer_variation'].median()
print(c2)
c3 = NFT_kpis_variation['Txn/Buyer_variation'].mean()
print(c3)
c4 = NFT_kpis_variation['Txn/Buyer_variation'].max()
print(c4)
c5 = NFT_kpis_variation['Txn/Buyer_variation'].std()
print(c5)
# Out:
# 0.8681740760591143
# 1.0054280637746587
# 1.090121649030729
# 2.9430137905077967
# 0.333038623470039

# %%
# Create dictionary with the variables and the results.
Final_Data = {
    '$/Txn_variation' : [0.12, 0.94, 1.11, 2.55, 0.49],
    '$/Buyer_variation' : [0.34, 0.99, 1.16, 2.82, 0.48],
    'Txn/Buyer_variation' : [0.87, 1.01, 1.09, 2.94, 0.33]
}

# %%
# Turn dictionary to Dataframe.
df_final_data = pd.DataFrame.from_dict(Final_Data, orient='index')
df_final_data.rename({0 : 'Min', 1: 'Median', 2:'Mean',3: 'Max', 4:'Std'}, axis = 1, inplace = True) 
df_final_data
# Out:
#                       Min  Median  Mean   Max   Std
# $/Txn_variation      0.12    0.94  1.11  2.55  0.49
# $/Buyer_variation    0.34    0.99  1.16  2.82  0.48
# Txn/Buyer_variation  0.87    1.01  1.09  2.94  0.33

# %% [markdown]
# ### Cleaning Conclusion
# We can see that although the NFT market as a whole has seen sharp declines in floor prices and sales volumes within collections, the top collections, these are the ones that have managed to stay in the top 100 since November 2021 until now, have experienced:
# 1. An increase in dollars spent per transaction
# 2. An increase in dollars spent per buyer
# 3. An increase in transactions per buyer
#
# Shown by the mean being > 1.
#
# Although values have a quite high standard deviation, the median suggests that ratios have remained constant, which is quite impressive taking into account market conditions. We need to consider that this sample contains mainly ethereum projects, so it may be a bit biased for the rest of blockchains.

# %%
df_final_data.to_csv('../dataset/final_kpis.csv')
